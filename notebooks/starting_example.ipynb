# %% [markdown]
# # Streamdaq v2: Data Quality Monitoring for Streams, Made Easy. More Easy.
#
# This is the basic notebook for streamdaq v2 documentation.

# %%
test = 1
if test > 0:
    print("Test is greater than 0")
print("End")
